# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
data_to_plot=pd.read_excel(r"C:\Users\Soumo\Documents\artificial_intelligence\data_dir\Emman Data Final Data Processed Time.xlsx")

# %%
data_to_plot.head()
# Out:
#    Temperature  Humidity  CO2  Soil Moisture
# 0         20.7        79  380             80
# 1         20.7        80  380             87
# 2         20.7        80  396             88
# 3         20.6        79  399             87
# 4         20.6        79  399             87

# %%
plt.plot(data_to_plot['Temperature'])
plt.xticks(range(0, 7608568, 22))
# Out:
# ([<matplotlib.axis.XTick at 0x23ee3ee1280>,
# ...
#   ...],
#  [Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
# ...

# %%
plt.xlabel('Time(second)')
plt.ylabel('temperature(degree)')
plt.title('Temperature recorded in function of time')
plt.legend()
plt.show()

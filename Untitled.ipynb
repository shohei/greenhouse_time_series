# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.utils import shuffle
import torch
import torch.nn as nn
import torch.optim as optimizers
from callbacks import EarlyStopping


class RNN(nn.Module):
    def __init__(self, hidden_dim):
        super().__init__()
        self.l1 = nn.GRU(1, hidden_dim,
                         batch_first=True)
        self.l2 = nn.Linear(hidden_dim, 1)

        nn.init.xavier_normal_(self.l1.weight_ih_l0)
        nn.init.orthogonal_(self.l1.weight_hh_l0)

    def forward(self, x):
        print(x.shape)
        print(self.l1)
        h, _ = self.l1(x)
        y = self.l2(h[:, -1])
        return y

# %%
    def sin(x, T=100):
        return np.sin(2.0 * np.pi * x / T)

    def toy_problem(T=100, ampl=0.05):
        x = np.arange(0, 2*T + 1)
        noise = ampl * np.random.uniform(low=-1.0, high=1.0,
                                         size=len(x))
        return sin(x) + noise

    T = 100
    f = toy_problem(T).astype(np.float32)
    length_of_sequences = len(f)
    maxlen = 25

    x = []
    t = []

    for i in range(length_of_sequences - maxlen):
        x.append(f[i:i+maxlen])
        t.append(f[i+maxlen])

    x = np.array(x).reshape(-1, maxlen, 1)
    t = np.array(t).reshape(-1, 1)

# %%
plt.plot(x[0],t)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_3852/4050941347.py in <module>
# ----> 1 plt.plot(x[0],t)
#
# ~/.local/lib/python3.8/site-packages/matplotlib/pyplot.py in plot(scalex, scaley, data, *args, **kwargs)
#    2755 @_copy_docstring_and_deprecators(Axes.plot)
#    2756 def plot(*args, scalex=True, scaley=True, data=None, **kwargs):
# -> 2757     return gca().plot(
#    2758         *args, scalex=scalex, scaley=scaley,
#    2759         **({"data": data} if data is not None else {}), **kwargs)
#
# ~/.local/lib/python3.8/site-packages/matplotlib/axes/_axes.py in plot(self, scalex, scaley, data, *args, **kwargs)
#    1630         """
#    1631         kwargs = cbook.normalize_kwargs(kwargs, mlines.Line2D)
# -> 1632         lines = [*self._get_lines(*args, data=data, **kwargs)]
#    1633         for line in lines:
#    1634             self.add_line(line)
#
# ~/.local/lib/python3.8/site-packages/matplotlib/axes/_base.py in __call__(self, data, *args, **kwargs)
#     310                 this += args[0],
#     311                 args = args[1:]
# --> 312             yield from self._plot_args(this, kwargs)
#     313
#     314     def get_next_color(self):
#
# ~/.local/lib/python3.8/site-packages/matplotlib/axes/_base.py in _plot_args(self, tup, kwargs, return_kwargs)
#     496
#     497         if x.shape[0] != y.shape[0]:
# --> 498             raise ValueError(f"x and y must have same first dimension, but "
#     499                              f"have shapes {x.shape} and {y.shape}")
#     500         if x.ndim > 2 or y.ndim > 2:
#
# ValueError: x and y must have same first dimension, but have shapes (25, 1) and (176, 1)

# %%
    np.random.seed(123)
    torch.manual_seed(123)
    device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

    '''
    1. データの準備
    '''

    x_train, x_val, t_train, t_val = \
        train_test_split(x, t, test_size=0.2, shuffle=False)

    '''
    2. モデルの構築
    '''
    model = RNN(50).to(device)

    '''
    3. モデルの学習
    '''
    criterion = nn.MSELoss(reduction='mean')
    optimizer = optimizers.Adam(model.parameters(),
                                lr=0.001,
                                betas=(0.9, 0.999), amsgrad=True)

    def compute_loss(t, y):
        return criterion(y, t)

    def train_step(x, t):
        x = torch.Tensor(x).to(device)
        t = torch.Tensor(t).to(device)
        model.train()
        preds = model(x)
        loss = compute_loss(t, preds)
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

        return loss, preds

    def val_step(x, t):
        x = torch.Tensor(x).to(device)
        t = torch.Tensor(t).to(device)
        model.eval()
        preds = model(x)
        loss = criterion(preds, t)

        return loss, preds

    epochs = 1000
    batch_size = 100
    n_batches_train = x_train.shape[0] // batch_size + 1
    n_batches_val = x_val.shape[0] // batch_size + 1
    hist = {'loss': [], 'val_loss': []}
    es = EarlyStopping(patience=10, verbose=1)

    for epoch in range(epochs):
        train_loss = 0.
        val_loss = 0.
        x_, t_ = shuffle(x_train, t_train)

        for batch in range(n_batches_train):
            start = batch * batch_size
            end = start + batch_size
            loss, _ = train_step(x_[start:end], t_[start:end])
            train_loss += loss.item()

        for batch in range(n_batches_val):
            start = batch * batch_size
            end = start + batch_size
            loss, _ = val_step(x_val[start:end], t_val[start:end])
            val_loss += loss.item()

        train_loss /= n_batches_train
        val_loss /= n_batches_val

        hist['loss'].append(train_loss)
        hist['val_loss'].append(val_loss)

        print('epoch: {}, loss: {:.3}, val_loss: {:.3f}'.format(
            epoch+1,
            train_loss,
            val_loss
        ))

        if es(val_loss):
            break
# Out:
# torch.Size([100, 25, 1])
# GRU(1, 50, batch_first=True)
# torch.Size([40, 25, 1])
# GRU(1, 50, batch_first=True)
# torch.Size([36, 25, 1])
# GRU(1, 50, batch_first=True)
# epoch:
val_loss: 0.002
# torch.Size([100, 25, 1])
# GRU(1, 50, batch_first=True)
# torch.Size([40, 25, 1])
# GRU(1, 50, batch_first=True)
# torch.Size([36, 25, 1])
# GRU(1, 50, batch_first=True)
# epoch: 70, loss: 0.00145, val_loss: 0.002
# torch.Size([100, 25, 1])
# GRU(1, 50, batch_first=True)
# torch.Size([40, 25, 1])
# GRU(1, 50, batch_first=True)
# torch.Size([36, 25, 1])
# GRU(1, 50, batch_first=True)
# epoch: 71, loss: 0.00165, val_loss: 0.001
# torch.Size([100, 25, 1])
# GRU(1, 50, batch_first=True)
# torch.Size([40, 25, 1])
# GRU(1, 50, batch_first=True)
# torch.Size([36, 25, 1])
# GRU(1, 50, batch_first=True)
# epoch: 72, loss: 0.00139, val_loss: 0.001
# torch.Size([100, 25, 1])
# GRU(1, 50, batch_first=True)
# torch.Size([40, 25, 1])
# GRU(1, 50, batch_first=True)
# torch.Size([36, 25, 1])
# GRU(1, 50, batch_first=True)
# epoch: 73, loss: 0.00143, val_loss: 0.001
# torch.Size([100, 25, 1])
# GRU(1, 50, batch_first=True)
# torch.Size([40, 25, 1])
# GRU(1, 50, batch_first=True)
# torch.Size([36, 25, 1])
# GRU(1, 50, batch_first=True)
# epoch: 74, loss: 0.00125, val_loss: 0.001
# torch.Size([100, 25, 1])
# GRU(1, 50, batch_first=True)
# torch.Size([40, 25, 1])
# GRU(1, 50, batch_first=True)
# torch.Size([36, 25, 1])
# GRU(1, 50, batch_first=True)
# epoch: 75, loss: 0.00141, val_loss: 0.001
# torch.Size([100, 25, 1])
# GRU(1, 50, batch_first=True)
# torch.Size([40, 25, 1])
# GRU(1, 50, batch_first=True)
# torch.Size([36, 25, 1])
# GRU(1, 50, batch_first=True)
# epoch: 76, loss: 0.00132, val_loss: 0.001
# torch.Size([100, 25, 1])
# GRU(1, 50, batch_first=True)
# torch.Size([40, 25, 1])
# GRU(1, 50, batch_first=True)
# torch.Size([36, 25, 1])
# GRU(1, 50, batch_first=True)
# epoch: 77, loss: 0.00141, val_loss: 0.001
# torch.Size([100, 25, 1])
# GRU(1, 50, batch_first=True)
# torch.Size([40, 25, 1])
# GRU(1, 50, batch_first=True)
# torch.Size([36, 25, 1])
# GRU(1, 50, batch_first=True)
# epoch: 78, loss: 0.00128, val_loss: 0.001
# torch.Size([100, 25, 1])
# GRU(1, 50, batch_first=True)
# torch.Size([40, 25, 1])
# GRU(1, 50, batch_first=True)
# torch.Size([36, 25, 1])
# GRU(1, 50, batch_first=True)
# epoch: 79, loss: 0.00127, val_loss: 0.001
# torch.Size([100, 25, 1])
# GRU(1, 50, batch_first=True)
# torch.Size([40, 25, 1])
# GRU(1, 50, batch_first=True)
# torch.Size([36, 25, 1])
# GRU(1, 50, batch_first=True)
# epoch: 80, loss: 0.00137, val_loss: 0.001
# torch.Size([100, 25, 1])
# GRU(1, 50, batch_first=True)
# torch.Size([40, 25, 1])
# GRU(1, 50, batch_first=True)
# torch.Size([36, 25, 1])
# GRU(1, 50, batch_first=True)
# epoch: 81, loss: 0.00135, val_loss: 0.001
# torch.Size([100, 25, 1])
# GRU(1, 50, batch_first=True)
# torch.Size([40, 25, 1])
# GRU(1, 50, batch_first=True)
# torch.Size([36, 25, 1])
# GRU(1, 50, batch_first=True)
# epoch: 82, loss: 0.00134, val_loss: 0.001
# torch.Size([100, 25, 1])
# GRU(1, 50, batch_first=True)
# torch.Size([40, 25, 1])
# GRU(1, 50, batch_first=True)
# torch.Size([36, 25, 1])
# GRU(1, 50, batch_first=True)
# epoch: 83, loss: 0.00133, val_loss: 0.001
# torch.Size([100, 25, 1])
# GRU(1, 50, batch_first=True)
# torch.Size([40, 25, 1])
# GRU(1, 50, batch_first=True)
# torch.Size([36, 25, 1])
# GRU(1, 50, batch_first=True)
# epoch: 84, loss: 0.00128, val_loss: 0.001
# torch.Size([100, 25, 1])
# GRU(1, 50, batch_first=True)
# torch.Size([40, 25, 1])
# GRU(1, 50, batch_first=True)
# torch.Size([36, 25, 1])
# GRU(1, 50, batch_first=True)
# epoch: 85, loss: 0.00136, val_loss: 0.001
# torch.Size([100, 25, 1])
# GRU(1, 50, batch_first=True)
# torch.Size([40, 25, 1])
# GRU(1, 50, batch_first=True)
# torch.Size([36, 25, 1])
# GRU(1, 50, batch_first=True)
# epoch: 86, loss: 0.0013, val_loss: 0.001
# torch.Size([100, 25, 1])
# GRU(1, 50, batch_first=True)
# torch.Size([40, 25, 1])
# GRU(1, 50, batch_first=True)
# torch.Size([36, 25, 1])
# GRU(1, 50, batch_first=True)
# epoch: 87, loss: 0.00142, val_loss: 0.001
# torch.Size([100, 25, 1])
# GRU(1, 50, batch_first=True)
# torch.Size([40, 25, 1])
# GRU(1, 50, batch_first=True)
# torch.Size([36, 25, 1])
# GRU(1, 50, batch_first=True)
# epoch: 88, loss: 0.00132, val_loss: 0.001
# torch.Size([100, 25, 1])
# GRU(1, 50, batch_first=True)
# torch.Size([40, 25, 1])
# GRU(1, 50, batch_first=True)
# torch.Size([36, 25, 1])
# GRU(1, 50, batch_first=True)
# epoch: 89, loss: 0.00136, val_loss: 0.001
# torch.Size([100, 25, 1])
# GRU(1, 50, batch_first=True)
# torch.Size([40, 25, 1])
# GRU(1, 50, batch_first=True)
# torch.Size([36, 25, 1])
# GRU(1, 50, batch_first=True)
# epoch: 90, loss: 0.00123, val_loss: 0.001
# torch.Size([100, 25, 1])
# GRU(1, 50, batch_first=True)
# torch.Size([40, 25, 1])
# GRU(1, 50, batch_first=True)
# torch.Size([36, 25, 1])
# GRU(1, 50, batch_first=True)
# epoch: 91, loss: 0.00127, val_loss: 0.001
# torch.Size([100, 25, 1])
# GRU(1, 50, batch_first=True)
# torch.Size([40, 25, 1])
# GRU(1, 50, batch_first=True)
# torch.Size([36, 25, 1])
# GRU(1, 50, batch_first=True)
# epoch: 92, loss: 0.00132, val_loss: 0.001
# torch.Size([100, 25, 1])
# GRU(1, 50, batch_first=True)
# torch.Size([40, 25, 1])
# GRU(1, 50, batch_first=True)
# torch.Size([36, 25, 1])
# GRU(1, 50, batch_first=True)
# epoch: 93, loss: 0.0013, val_loss: 0.001
# torch.Size([100, 25, 1])
# GRU(1, 50, batch_first=True)
# torch.Size([40, 25, 1])
# GRU(1, 50, batch_first=True)
# torch.Size([36, 25, 1])
# GRU(1, 50, batch_first=True)
# epoch: 94, loss: 0.00119, val_loss: 0.001
# torch.Size([100, 25, 1])
# GRU(1, 50, batch_first=True)
# torch.Size([40, 25, 1])
# GRU(1, 50, batch_first=True)
# torch.Size([36, 25, 1])
# GRU(1, 50, batch_first=True)
# epoch: 95, loss: 0.00132, val_loss: 0.001
# torch.Size([100, 25, 1])
# GRU(1, 50, batch_first=True)
# torch.Size([40, 25, 1])
# GRU(1, 50, batch_first=True)
# torch.Size([36, 25, 1])
# GRU(1, 50, batch_first=True)
# epoch: 96, loss: 0.00117, val_loss: 0.001
# torch.Size([100, 25, 1])
# GRU(1, 50, batch_first=True)
# torch.Size([40, 25, 1])
# GRU(1, 50, batch_first=True)
# torch.Size([36, 25, 1])
# GRU(1, 50, batch_first=True)
# epoch: 97, loss: 0.00119, val_loss: 0.001
# torch.Size([100, 25, 1])
# GRU(1, 50, batch_first=True)
# torch.Size([40, 25, 1])
# GRU(1, 50, batch_first=True)
# torch.Size([36, 25, 1])
# GRU(1, 50, batch_first=True)
# epoch: 98, loss: 0.00134, val_loss: 0.001
# torch.Size([100, 25, 1])
# GRU(1, 50, batch_first=True)
# torch.Size([40, 25, 1])
# GRU(1, 50, batch_first=True)
# torch.Size([36, 25, 1])
# GRU(1, 50, batch_first=True)
# epoch: 99, loss: 0.00132, val_loss: 0.001
# torch.Size([100, 25, 1])
# GRU(1, 50, batch_first=True)
# torch.Size([40, 25, 1])
# GRU(1, 50, batch_first=True)
# torch.Size([36, 25, 1])
# GRU(1, 50, batch_first=True)
# epoch: 100, loss: 0.00122, val_loss: 0.001
# torch.Size([100, 25, 1])
# GRU(1, 50, batch_first=True)
# torch.Size([40, 25, 1])
# GRU(1, 50, batch_first=True)
# torch.Size([36, 25, 1])
# GRU(1, 50, batch_first=True)
# epoch: 101, loss: 0.00133, val_loss: 0.001
# torch.Size([100, 25, 1])
# GRU(1, 50, batch_first=True)
# torch.Size([40, 25, 1])
# GRU(1, 50, batch_first=True)
# torch.Size([36, 25, 1])
# GRU(1, 50, batch_first=True)
# epoch: 102, loss: 0.00126, val_loss: 0.001
# torch.Size([100, 25, 1])
# GRU(1, 50, batch_first=True)
# torch.Size([40, 25, 1])
# GRU(1, 50, batch_first=True)
# torch.Size([36, 25, 1])
# GRU(1, 50, batch_first=True)
# epoch: 103, loss: 0.0013, val_loss: 0.001
# torch.Size([100, 25, 1])
# GRU(1, 50, batch_first=True)
# torch.Size([40, 25, 1])
# GRU(1, 50, batch_first=True)
# torch.Size([36, 25, 1])
# GRU(1, 50, batch_first=True)
# epoch: 104, loss: 0.00126, val_loss: 0.001
# torch.Size([100, 25, 1])
# GRU(1, 50, batch_first=True)
# torch.Size([40, 25, 1])
# GRU(1, 50, batch_first=True)
# torch.Size([36, 25, 1])
# GRU(1, 50, batch_first=True)
# epoch: 105, loss: 0.00127, val_loss: 0.001
# torch.Size([100, 25, 1])
# GRU(1, 50, batch_first=True)
# torch.Size([40, 25, 1])
# GRU(1, 50, batch_first=True)
# torch.Size([36, 25, 1])
# GRU(1, 50, batch_first=True)
# epoch: 106, loss: 0.00139, val_loss: 0.001
# torch.Size([100, 25, 1])
# GRU(1, 50, batch_first=True)
# torch.Size([40, 25, 1])
# GRU(1, 50, batch_first=True)
# torch.Size([36, 25, 1])
# GRU(1, 50, batch_first=True)
# epoch: 107, loss: 0.00131, val_loss: 0.001
# torch.Size([100, 25, 1])
# GRU(1, 50, batch_first=True)
# torch.Size([40, 25, 1])
# GRU(1, 50, batch_first=True)
# torch.Size([36, 25, 1])
# GRU(1, 50, batch_first=True)
# epoch: 108, loss: 0.00133, val_loss: 0.001
# torch.Size([100, 25, 1])
# GRU(1, 50, batch_first=True)
# torch.Size([40, 25, 1])
# GRU(1, 50, batch_first=True)
# torch.Size([36, 25, 1])
# GRU(1, 50, batch_first=True)
# epoch: 109, loss: 0.00125, val_loss: 0.001
# torch.Size([100, 25, 1])
# GRU(1, 50, batch_first=True)
# torch.Size([40, 25, 1])
# GRU(1, 50, batch_first=True)
# torch.Size([36, 25, 1])
# GRU(1, 50, batch_first=True)
# epoch: 110, loss: 0.00122, val_loss: 0.001
# torch.Size([100, 25, 1])
# GRU(1, 50, batch_first=True)
# torch.Size([40, 25, 1])
# GRU(1, 50, batch_first=True)
# torch.Size([36, 25, 1])
# GRU(1, 50, batch_first=True)
# epoch: 111, loss: 0.00126, val_loss: 0.001
# torch.Size([100, 25, 1])
# GRU(1, 50, batch_first=True)
# torch.Size([40, 25, 1])
# GRU(1, 50, batch_first=True)
# torch.Size([36, 25, 1])
# GRU(1, 50, batch_first=True)
# epoch: 112, loss: 0.00135, val_loss: 0.001
# torch.Size([100, 25, 1])
# GRU(1, 50, batch_first=True)
# torch.Size([40, 25, 1])
# GRU(1, 50, batch_first=True)
# torch.Size([36, 25, 1])
# GRU(1, 50, batch_first=True)
# epoch: 113, loss: 0.00119, val_loss: 0.001
# torch.Size([100, 25, 1])
# GRU(1, 50, batch_first=True)
# torch.Size([40, 25, 1])
# GRU(1, 50, batch_first=True)
# torch.Size([36, 25, 1])
# GRU(1, 50, batch_first=True)
# epoch: 114, loss: 0.00135, val_loss: 0.001
# torch.Size([100, 25, 1])
# GRU(1, 50, batch_first=True)
# torch.Size([40, 25, 1])
# GRU(1, 50, batch_first=True)
# torch.Size([36, 25, 1])
# GRU(1, 50, batch_first=True)
# epoch: 115, loss: 0.00131, val_loss: 0.001
# torch.Size([100, 25, 1])
# GRU(1, 50, batch_first=True)
# torch.Size([40, 25, 1])
# GRU(1, 50, batch_first=True)
# torch.Size([36, 25, 1])
# GRU(1, 50, batch_first=True)
# epoch: 116, loss: 0.00128, val_loss: 0.001
# torch.Size([100, 25, 1])
# GRU(1, 50, batch_first=True)
# torch.Size([40, 25, 1])
# GRU(1, 50, batch_first=True)
# torch.Size([36, 25, 1])
# GRU(1, 50, batch_first=True)
# epoch: 117, loss: 0.00121, val_loss: 0.001
# torch.Size([100, 25, 1])
# GRU(1, 50, batch_first=True)
# torch.Size([40, 25, 1])
# GRU(1, 50, batch_first=True)
# torch.Size([36, 25, 1])
# GRU(1, 50, batch_first=True)
# epoch: 118, loss: 0.00125, val_loss: 0.001
# torch.Size([100, 25, 1])
# GRU(1, 50, batch_first=True)
# torch.Size([40, 25, 1])
# GRU(1, 50, batch_first=True)
# torch.Size([36, 25, 1])
# GRU(1, 50, batch_first=True)
# epoch: 119, loss: 0.00137, val_loss: 0.001
# torch.Size([100, 25, 1])
# GRU(1, 50, batch_first=True)
# torch.Size([40, 25, 1])
# GRU(1, 50, batch_first=True)
# torch.Size([36, 25, 1])
# GRU(1, 50, batch_first=True)
# epoch: 120, loss: 0.00127, val_loss: 0.001
# torch.Size([100, 25, 1])
# GRU(1, 50, batch_first=True)
# torch.Size([40, 25, 1])
# GRU(1, 50, batch_first=True)
# torch.Size([36, 25, 1])
# GRU(1, 50, batch_first=True)
# epoch: 121, loss: 0.00113, val_loss: 0.001
# torch.Size([100, 25, 1])
# GRU(1, 50, batch_first=True)
# torch.Size([40, 25, 1])
# GRU(1, 50, batch_first=True)
# torch.Size([36, 25, 1])
# GRU(1, 50, batch_first=True)
# epoch: 122, loss: 0.00129, val_loss: 0.001
# torch.Size([100, 25, 1])
# GRU(1, 50, batch_first=True)
# torch.Size([40, 25, 1])
# GRU(1, 50, batch_first=True)
# torch.Size([36, 25, 1])
# GRU(1, 50, batch_first=True)
# epoch: 123, loss: 0.00129, val_loss: 0.001
# torch.Size([100, 25, 1])
# GRU(1, 50, batch_first=True)
# torch.Size([40, 25, 1])
# GRU(1, 50, batch_first=True)
# torch.Size([36, 25, 1])
# GRU(1, 50, batch_first=True)
# epoch: 124, loss: 0.00125, val_loss: 0.001
# torch.Size([100, 25, 1])
# GRU(1, 50, batch_first=True)
# torch.Size([40, 25, 1])
# GRU(1, 50, batch_first=True)
# torch.Size([36, 25, 1])
# GRU(1, 50, batch_first=True)
# epoch: 125, loss: 0.00129, val_loss: 0.001
# torch.Size([100, 25, 1])
# GRU(1, 50, batch_first=True)
# torch.Size([40, 25, 1])
# GRU(1, 50, batch_first=True)
# torch.Size([36, 25, 1])
# GRU(1, 50, batch_first=True)
# epoch: 126, loss: 0.00128, val_loss: 0.001
# torch.Size([100, 25, 1])
# GRU(1, 50, batch_first=True)
# torch.Size([40, 25, 1])
# GRU(1, 50, batch_first=True)
# torch.Size([36, 25, 1])
# GRU(1, 50, batch_first=True)
# epoch: 127, loss: 0.00117, val_loss: 0.001
# torch.Size([100, 25, 1])
# GRU(1, 50, batch_first=True)
# torch.Size([40, 25, 1])
# GRU(1, 50, batch_first=True)
# torch.Size([36, 25, 1])
# GRU(1, 50, batch_first=True)
# epoch: 128, loss: 0.00118, val_loss: 0.001
# torch.Size([100, 25, 1])
# GRU(1, 50, batch_first=True)
# torch.Size([40, 25, 1])
# GRU(1, 50, batch_first=True)
# torch.Size([36, 25, 1])
# GRU(1, 50, batch_first=True)
# epoch: 129, loss: 0.00128, val_loss: 0.001
# torch.Size([100, 25, 1])
# GRU(1, 50, batch_first=True)
# torch.Size([40, 25, 1])
# GRU(1, 50, batch_first=True)
# torch.Size([36, 25, 1])
# GRU(1, 50, batch_first=True)
# epoch: 130, loss: 0.00138, val_loss: 0.001
# torch.Size([100, 25, 1])
# GRU(1, 50, batch_first=True)
# torch.Size([40, 25, 1])
# GRU(1, 50, batch_first=True)
# torch.Size([36, 25, 1])
# GRU(1, 50, batch_first=True)
# epoch: 131, loss: 0.00131, val_loss: 0.001
# torch.Size([100, 25, 1])
# GRU(1, 50, batch_first=True)
# torch.Size([40, 25, 1])
# GRU(1, 50, batch_first=True)
# torch.Size([36, 25, 1])
# GRU(1, 50, batch_first=True)
# epoch: 132, loss: 0.00123, val_loss: 0.001
# torch.Size([100, 25, 1])
# GRU(1, 50, batch_first=True)
# torch.Size([40, 25, 1])
# GRU(1, 50, batch_first=True)
# torch.Size([36, 25, 1])
# GRU(1, 50, batch_first=True)
# epoch: 133, loss: 0.00127, val_loss: 0.001
# torch.Size([100, 25, 1])
# GRU(1, 50, batch_first=True)
# torch.Size([40, 25, 1])
# GRU(1, 50, batch_first=True)
# torch.Size([36, 25, 1])
# GRU(1, 50, batch_first=True)
# epoch: 134, loss: 0.00131, val_loss: 0.001
# torch.Size([100, 25, 1])
# GRU(1, 50, batch_first=True)
# torch.Size([40, 25, 1])
# GRU(1, 50, batch_first=True)
# torch.Size([36, 25, 1])
# GRU(1, 50, batch_first=True)
# epoch: 135, loss: 0.00136, val_loss: 0.001
# torch.Size([100, 25, 1])
# GRU(1, 50, batch_first=True)
# torch.Size([40, 25, 1])
# GRU(1, 50, batch_first=True)
# torch.Size([36, 25, 1])
# GRU(1, 50, batch_first=True)
# epoch: 136, loss: 0.00122, val_loss: 0.001
# torch.Size([100, 25, 1])
# GRU(1, 50, batch_first=True)
# torch.Size([40, 25, 1])
# GRU(1, 50, batch_first=True)
# torch.Size([36, 25, 1])
# GRU(1, 50, batch_first=True)
# epoch: 137, loss: 0.00138, val_loss: 0.001
# torch.Size([100, 25, 1])
# GRU(1, 50, batch_first=True)
# torch.Size([40, 25, 1])
# GRU(1, 50, batch_first=True)
# torch.Size([36, 25, 1])
# GRU(1, 50, batch_first=True)
# epoch: 138, loss: 0.00131, val_loss: 0.001
# torch.Size([100, 25, 1])
# GRU(1, 50, batch_first=True)
# torch.Size([40, 25, 1])
# GRU(1, 50, batch_first=True)
# torch.Size([36, 25, 1])
# GRU(1, 50, batch_first=True)
# epoch: 139, loss: 0.00128, val_loss: 0.001
# torch.Size([100, 25, 1])
# GRU(1, 50, batch_first=True)
# torch.Size([40, 25, 1])
# GRU(1, 50, batch_first=True)
# torch.Size([36, 25, 1])
# GRU(1, 50, batch_first=True)
# epoch: 140, loss: 0.00124, val_loss: 0.001
# torch.Size([100, 25, 1])
# GRU(1, 50, batch_first=True)
# torch.Size([40, 25, 1])
# GRU(1, 50, batch_first=True)
# torch.Size([36, 25, 1])
# GRU(1, 50, batch_first=True)
# epoch: 141, loss: 0.00126, val_loss: 0.001
# torch.Size([100, 25, 1])
# GRU(1, 50, batch_first=True)
# torch.Size([40, 25, 1])
# GRU(1, 50, batch_first=True)
# torch.Size([36, 25, 1])
# GRU(1, 50, batch_first=True)
# epoch: 142, loss: 0.00125, val_loss: 0.001
# early stopping

# %%
    model.eval()

    # sin波の予測
    sin = toy_problem(T, ampl=0.)
    gen = [None for i in range(maxlen)]

    z = x[:1]

    for i in range(length_of_sequences - maxlen):
        z_ = torch.Tensor(z[-1:]).to(device)
        preds = model(z_).data.cpu().numpy()
        z = np.append(z, preds)[1:]
        z = z.reshape(-1, maxlen, 1)
        gen.append(preds[0, 0])

# %%
print(z.shape)
print(x.shape)
# Out:
# (1, 25, 1)
# (176, 25, 1)

# %%
    # 予測値を可視化
    fig = plt.figure()
    plt.rc('font', family='serif')
    plt.xlim([0, 2*T])
    plt.ylim([-1.5, 1.5])
    plt.plot(range(len(f)), sin,
             color='gray',
             linestyle='--', linewidth=0.5)
    plt.plot(range(len(f)), gen,
             color='black', linewidth=1,
             marker='o', markersize=1, markerfacecolor='black',
             markeredgecolor='black')
    # plt.savefig('output.jpg')
    plt.show()

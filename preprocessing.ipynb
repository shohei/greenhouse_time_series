# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("data.csv")
df
# Out:
#            Time  Temperature  Humidity    CO2  Soil Moisture
# 0            22         20.7      79.0  380.0           80.0
# 1            44         20.7      80.0  380.0           87.0
# 2            66         20.7      80.0  396.0           88.0
# 3            88         20.6      79.0  399.0           87.0
# 4           110         20.6      79.0  399.0           87.0
# ...         ...          ...       ...    ...            ...
# 345840  7608502         20.7      79.0  404.0           86.0
# 345841  7608524         20.7      79.0  408.0           87.0
# 345842  7608546         20.7      79.0  408.0           87.0
# 345843  7608568         20.7      79.0  420.0           86.0
# 345844  7608590          NaN       NaN    NaN            NaN
#
# [345845 rows x 5 columns]

# %%
co2 = df['CO2']

# %%
co2.describe()
sns.boxplot(co2)
# Out:
# /Users/shohei/.pyenv/versions/3.9.2/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='CO2'>

# %%
co2.describe()
# Out:
# count    345844.000000
# mean        385.305074
# std          22.442970
# min         276.000000
# 25%         369.000000
# 50%         384.000000
# 75%         404.000000
# max         446.000000
# Name: CO2, dtype: float64

# %%
co2.plot()
# Out:
# <AxesSubplot:>

# %%
def lowcut(_df, th):
    _df = _df.copy()
    n = len(_df)    
    for i in range(n):
        x = _df.iloc[i]
        if x < th:
            _df.iloc[i] = _df.iloc[i-1]    
    return _df

# %%
th = 330
co2_pre = lowcut(co2, 325)

# %%
co2_pre.plot()
# Out:
# <AxesSubplot:>

# %%
temp = df['Temperature']
temp.plot()
# Out:
# <AxesSubplot:>

# %%
rh = df['Humidity']
rh.plot()
# Out:
# <AxesSubplot:>

# %%
sm = df['Soil Moisture']
sm.plot()
# Out:
# <AxesSubplot:>

# %%
th = 65
sm_pre = lowcut(sm,th)
sm_pre.plot()
# Out:
# <AxesSubplot:>

# %%
def jumpcut(_df, th):
    _df = _df.copy()
    n = len(_df)    
    for i in range(n):
        x = df.iloc[i]
        if i<10000 and x<
        
    return _df

# %%
sm_pre.plot()
# Out:
# <AxesSubplot:>

# %%
th = 20
sm_pre2 = jumpcut(sm_pre,th)
sm_pre2.plot()
# Out:
# <AxesSubplot:>
